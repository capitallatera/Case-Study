# %% [markdown]
# <a href="https://colab.research.google.com/github/capitallatera/Case-Study/blob/master/Technology_Monitoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/Monitoring.xlsx")

# %%
# df

# %%
df.isnull().sum()
# Out:
# Technology     0
# A             25
# B             25
# C             24
# D              8
# E              8
# F              6
# G              0
# H              0
# I              0
# dtype: int64

# %%
df[['Technology','G','H']]
# Out:
#                  Technology     G     H
# 0             React Native    100   105
# 1                  React.js   342   346
# 2                   Angular   618   609
# 3                   Node.js   380   372
# 4                   mongodb   185   187
# 5                express.js   153   153
# 6                    django   142   149
# 7                javascript  2446  2459
# 8                    Vue.js   146   143
# 9                       sql  2595  2619
# 10                  flutter    63    59
# 11         machine learning   417   438
# 12              Go language   152   161
# 13               full stack   212   206
# 14               mean stack   554   556
# 15               mern stack    20    23
# 16                      php  1693  1702
# 17             data analyst   733   717
# 18           data scientist   296   235
# 19  artificial intelligence   231   220
# 20                      nlp    79    88
# 21                   python  1120  1139
# 22                java(215)  1834  1868
# 23      front end developer   334   345
# 24       back end developer   213   217
# 25                     .net   910   905
# 26              restful api   178   189
# 27               typescript    77    71
# 28                  tableau   101    93
# 29                 power bi    68    76
# 30       software developer  4990  4940
# 31        software engineer  3413  1377
# 32           java developer   697   714
# 33         python developer   363   381
# 34          c/c++ developer   215   214
# 35     javascript developer  1160  1186

# %%
import matplotlib.pyplot as plt

# %%
# Previous Data
fig=plt.subplots(figsize=(20,7))
# df['G']
# df['H']
plt.bar(df['Technology'],df['G'])
plt.xticks(rotation=90)
plt.show()

# %%
# Date April 6, 2021
fig,ax=plt.subplots(figsize=(20,7))
plt.bar(df['Technology'],df['H'])
plt.xticks(rotation=90)
# for i,j,z in zip(l3,df['H'],df['Change']):
#   ax.text(i,j,z,)
plt.show()

# %%
# Changes occur
df[['Technology','G','H']].plot(x='Technology',kind='bar',figsize=(20,7),)

# %%
l3=[]
for i in range(-1,len(df)-1):
  l3.append(str(i+0.5))
  # print(i/2)

# %%
# len(l3)
l3
# Out:
# ['-0.5',
#  '0.5',
#  '1.5',
#  '2.5',
#  '3.5',
#  '4.5',
#  '5.5',
#  '6.5',
#  '7.5',
#  '8.5',
#  '9.5',
#  '10.5',
#  '11.5',
#  '12.5',
#  '13.5',
#  '14.5',
#  '15.5',
#  '16.5',
#  '17.5',
#  '18.5',
#  '19.5',
#  '20.5',
#  '21.5',
#  '22.5',
#  '23.5',
#  '24.5',
#  '25.5',
#  '26.5',
#  '27.5',
#  '28.5',
#  '29.5',
#  '30.5',
#  '31.5',
#  '32.5',
#  '33.5',
#  '34.5']

# %%
l1=[]
l2=[]
def fun(x):
  if str(x)[0]=='-':
    l1.append(str(x)[1:])
    l2.append('Decrease')
    return (str(x)[1:],"Decrease")
  else:
    l1.append(str(x))
    l2.append('Increase')
    return (str(x),"Increase")

# %%
for i in range(len(df)):
  fun(round(((df['H'][i]-df['G'][i])/df['G'][i])*100,2))

# %%
df['% age']=l1
df['Change']=l2

# %%
df
# Out:
#                  Technology        A        B  ...     I  % age    Change
# 0             React Native     262.0    267.0  ...   116    5.0  Increase
# 1                  React.js    425.0    423.0  ...   326   1.17  Increase
# 2                   Angular    364.0    366.0  ...   615   1.46  Decrease
# 3                   Node.js   1229.0   1217.0  ...   354   2.11  Decrease
# 4                   mongodb   1347.0   1415.0  ...   187   1.08  Increase
# 5                express.js     91.0     91.0  ...   145    0.0  Increase
# 6                    django    261.0    255.0  ...   150   4.93  Increase
# 7                javascript   1255.0   1247.0  ...  2480   0.53  Increase
# 8                    Vue.js     95.0     97.0  ...   131   2.05  Decrease
# 9                       sql  19452.0  18744.0  ...  2697   0.92  Increase
# 10                  flutter    492.0    471.0  ...    62   6.35  Decrease
# 11         machine learning      NaN      NaN  ...   487   5.04  Increase
# 12              Go language      NaN      NaN  ...   162   5.92  Increase
# 13               full stack      NaN      NaN  ...   196   2.83  Decrease
# 14               mean stack      NaN      NaN  ...   534   0.36  Increase
# 15               mern stack      NaN      NaN  ...    15   15.0  Increase
# 16                      php      NaN      NaN  ...  1701   0.53  Increase
# 17             data analyst      NaN      NaN  ...   790   2.18  Decrease
# 18           data scientist      NaN      NaN  ...   351  20.61  Decrease
# 19  artificial intelligence      NaN      NaN  ...   228   4.76  Decrease
# 20                      nlp      NaN      NaN  ...    89  11.39  Increase
# 21                   python      NaN      NaN  ...  1195    1.7  Increase
# 22                java(215)      NaN      NaN  ...  1931   1.85  Increase
# 23      front end developer      NaN      NaN  ...   338   3.29  Increase
# 24       back end developer      NaN      NaN  ...   227   1.88  Increase
# 25                     .net      NaN      NaN  ...   959   0.55  Decrease
# 26              restful api      NaN      NaN  ...   183   6.18  Increase
# 27               typescript      NaN      NaN  ...    69   7.79  Decrease
# 28                  tableau      NaN      NaN  ...    96   7.92  Decrease
# 29                 power bi      NaN      NaN  ...    81  11.76  Increase
# 30       software developer      NaN      NaN  ...  4904    1.0  Decrease
# 31        software engineer      NaN      NaN  ...  1450  59.65  Decrease
# 32           java developer      NaN      NaN  ...   727   2.44  Increase
# 33         python developer      NaN      NaN  ...   383   4.96  Increase
# 34          c/c++ developer      NaN      NaN  ...   215   0.47  Decrease
# 35     javascript developer      NaN      NaN  ...  1178   2.24  Increase
#
# [36 rows x 12 columns]

# %% [markdown]
# Change ----> Date April 6, 2021

# %%
df[['Technology','H','I']]
# Out:
#                  Technology     H     I
# 0             React Native    105   116
# 1                  React.js   346   326
# 2                   Angular   609   615
# 3                   Node.js   372   354
# 4                   mongodb   187   187
# 5                express.js   153   145
# 6                    django   149   150
# 7                javascript  2459  2480
# 8                    Vue.js   143   131
# 9                       sql  2619  2697
# 10                  flutter    59    62
# 11         machine learning   438   487
# 12              Go language   161   162
# 13               full stack   206   196
# 14               mean stack   556   534
# 15               mern stack    23    15
# 16                      php  1702  1701
# 17             data analyst   717   790
# 18           data scientist   235   351
# 19  artificial intelligence   220   228
# 20                      nlp    88    89
# 21                   python  1139  1195
# 22                java(215)  1868  1931
# 23      front end developer   345   338
# 24       back end developer   217   227
# 25                     .net   905   959
# 26              restful api   189   183
# 27               typescript    71    69
# 28                  tableau    93    96
# 29                 power bi    76    81
# 30       software developer  4940  4904
# 31        software engineer  1377  1450
# 32           java developer   714   727
# 33         python developer   381   383
# 34          c/c++ developer   214   215
# 35     javascript developer  1186  1178

# %%
import matplotlib.pyplot as plt
# Previous Data
fig=plt.subplots(figsize=(20,7))
# df['G']
# df['H']
plt.bar(df['Technology'],df['H'])
plt.xticks(rotation=90)
plt.show()

# %%
# Date April 22, 2021
fig,ax=plt.subplots(figsize=(20,7))
plt.bar(df['Technology'],df['I'])
plt.xticks(rotation=90)
# for i,j,z in zip(l3,df['H'],df['Change']):
#   ax.text(i,j,z,)
plt.show()

# %%
# Changes occur
df[['Technology','H','I']].plot(x='Technology',kind='bar',figsize=(20,7),)

# %%
l1=[]
l2=[]
def fun(x):
  if str(x)[0]=='-':
    l1.append(str(x)[1:])
    l2.append('Decrease')
    return (str(x)[1:],"Decrease")
  else:
    l1.append(str(x))
    l2.append('Increase')
    return (str(x),"Increase")

# %%
for i in range(len(df)):
  fun(round(((df['I'][i]-df['H'][i])/df['H'][i])*100,2))

# %%
df['% age1']=l1
df['Change1']=l2

# %%
df
# Out:
#                  Technology        A        B  ...    Change  % age1   Change1
# 0             React Native     262.0    267.0  ...  Increase   10.48  Increase
# 1                  React.js    425.0    423.0  ...  Increase    5.78  Decrease
# 2                   Angular    364.0    366.0  ...  Decrease    0.99  Increase
# 3                   Node.js   1229.0   1217.0  ...  Decrease    4.84  Decrease
# 4                   mongodb   1347.0   1415.0  ...  Increase     0.0  Increase
# 5                express.js     91.0     91.0  ...  Increase    5.23  Decrease
# 6                    django    261.0    255.0  ...  Increase    0.67  Increase
# 7                javascript   1255.0   1247.0  ...  Increase    0.85  Increase
# 8                    Vue.js     95.0     97.0  ...  Decrease    8.39  Decrease
# 9                       sql  19452.0  18744.0  ...  Increase    2.98  Increase
# 10                  flutter    492.0    471.0  ...  Decrease    5.08  Increase
# 11         machine learning      NaN      NaN  ...  Increase   11.19  Increase
# 12              Go language      NaN      NaN  ...  Increase    0.62  Increase
# 13               full stack      NaN      NaN  ...  Decrease    4.85  Decrease
# 14               mean stack      NaN      NaN  ...  Increase    3.96  Decrease
# 15               mern stack      NaN      NaN  ...  Increase   34.78  Decrease
# 16                      php      NaN      NaN  ...  Increase    0.06  Decrease
# 17             data analyst      NaN      NaN  ...  Decrease   10.18  Increase
# 18           data scientist      NaN      NaN  ...  Decrease   49.36  Increase
# 19  artificial intelligence      NaN      NaN  ...  Decrease    3.64  Increase
# 20                      nlp      NaN      NaN  ...  Increase    1.14  Increase
# 21                   python      NaN      NaN  ...  Increase    4.92  Increase
# 22                java(215)      NaN      NaN  ...  Increase    3.37  Increase
# 23      front end developer      NaN      NaN  ...  Increase    2.03  Decrease
# 24       back end developer      NaN      NaN  ...  Increase    4.61  Increase
# 25                     .net      NaN      NaN  ...  Decrease    5.97  Increase
# 26              restful api      NaN      NaN  ...  Increase    3.17  Decrease
# 27               typescript      NaN      NaN  ...  Decrease    2.82  Decrease
# 28                  tableau      NaN      NaN  ...  Decrease    3.23  Increase
# 29                 power bi      NaN      NaN  ...  Increase    6.58  Increase
# 30       software developer      NaN      NaN  ...  Decrease    0.73  Decrease
# 31        software engineer      NaN      NaN  ...  Decrease     5.3  Increase
# 32           java developer      NaN      NaN  ...  Increase    1.82  Increase
# 33         python developer      NaN      NaN  ...  Increase    0.52  Increase
# 34          c/c++ developer      NaN      NaN  ...  Decrease    0.47  Increase
# 35     javascript developer      NaN      NaN  ...  Increase    0.67  Decrease
#
# [36 rows x 14 columns]
