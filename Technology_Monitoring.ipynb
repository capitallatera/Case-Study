# %% [markdown]
# <a href="https://colab.research.google.com/github/capitallatera/Case-Study/blob/master/Technology_Monitoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/Monitoring.xlsx")

# %%
# df

# %%
df.isnull().sum()
# Out:
# Technology     0
# A             25
# B             25
# C             24
# D              8
# E              8
# F              6
# G              0
# H              0
# I              0
# J              0
# dtype: int64

# %%
df[['Technology','G','H']]
# Out:
#                  Technology     G     H
# 0             React Native    100   105
# 1                  React.js   342   346
# 2                   Angular   618   609
# 3                   Node.js   380   372
# 4                   mongodb   185   187
# 5                express.js   153   153
# 6                    django   142   149
# 7                javascript  2446  2459
# 8                    Vue.js   146   143
# 9                       sql  2595  2619
# 10                  flutter    63    59
# 11         machine learning   417   438
# 12              Go language   152   161
# 13               full stack   212   206
# 14               mean stack   554   556
# 15               mern stack    20    23
# 16                      php  1693  1702
# 17             data analyst   733   717
# 18           data scientist   296   235
# 19  artificial intelligence   231   220
# 20                      nlp    79    88
# 21                   python  1120  1139
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Previous Data
fig=plt.subplots(figsize=(20,7))
# df['G']
# df['H']
plt.bar(df['Technology'],df['G'])
plt.xticks(rotation=90)
plt.show()

# %%
# Date April 6, 2021
fig,ax=plt.subplots(figsize=(20,7))
plt.bar(df['Technology'],df['H'])
plt.xticks(rotation=90)
# for i,j,z in zip(l3,df['H'],df['Change']):
#   ax.text(i,j,z,)
plt.show()

# %%
# Changes occur
df[['Technology','G','H']].plot(x='Technology',kind='bar',figsize=(20,7),)

# %%
l3=[]
for i in range(-1,len(df)-1):
  l3.append(str(i+0.5))
  # print(i/2)

# %%
# len(l3)
l3
# Out:
# ['-0.5',
#  '0.5',
#  '1.5',
#  '2.5',
#  '3.5',
#  '4.5',
#  '5.5',
#  '6.5',
#  '7.5',
#  '8.5',
#  '9.5',
#  '10.5',
#  '11.5',
#  '12.5',
#  '13.5',
#  '14.5',
#  '15.5',
#  '16.5',
#  '17.5',
#  '18.5',
#  '19.5',
#  '20.5',
#  '21.5',
#  '22.5',
#  '23.5',
#  '24.5',
#  '25.5',
#  '26.5',
#  '27.5',
#  '28.5',
#  '29.5',
#  '30.5',
#  '31.5',
#  '32.5',
#  '33.5',
#  '34.5']

# %%
l1=[]
l2=[]
def fun(x):
  if str(x)[0]=='-':
    l1.append(str(x)[1:])
    l2.append('Decrease')
    return (str(x)[1:],"Decrease")
  else:
    l1.append(str(x))
    l2.append('Increase')
    return (str(x),"Increase")

# %%
for i in range(len(df)):
  fun(round(((df['H'][i]-df['G'][i])/df['G'][i])*100,2))

# %%
df['% age']=l1
df['Change']=l2

# %%
df
# Out:
#                  Technology        A        B  ...     J  % age    Change
# 0             React Native     262.0    267.0  ...   105    5.0  Increase
# 1                  React.js    425.0    423.0  ...   307   1.17  Increase
# 2                   Angular    364.0    366.0  ...   518   1.46  Decrease
# 3                   Node.js   1229.0   1217.0  ...   318   2.11  Decrease
# 4                   mongodb   1347.0   1415.0  ...   161   1.08  Increase
# 5                express.js     91.0     91.0  ...   142    0.0  Increase
# 6                    django    261.0    255.0  ...   110   4.93  Increase
# 7                javascript   1255.0   1247.0  ...  2203   0.53  Increase
# 8                    Vue.js     95.0     97.0  ...   129   2.05  Decrease
# 9                       sql  19452.0  18744.0  ...  2341   0.92  Increase
# 10                  flutter    492.0    471.0  ...    61   6.35  Decrease
# 11         machine learning      NaN      NaN  ...   344   5.04  Increase
# ...

# %% [markdown]
# Change ----> Date April 6, 2021

# %%
df[['Technology','H','I']]
# Out:
#                  Technology     H     I
# 0             React Native    105   116
# 1                  React.js   346   326
# 2                   Angular   609   615
# 3                   Node.js   372   354
# 4                   mongodb   187   187
# 5                express.js   153   145
# 6                    django   149   150
# 7                javascript  2459  2480
# 8                    Vue.js   143   131
# 9                       sql  2619  2697
# 10                  flutter    59    62
# 11         machine learning   438   487
# 12              Go language   161   162
# 13               full stack   206   196
# 14               mean stack   556   534
# 15               mern stack    23    15
# 16                      php  1702  1701
# 17             data analyst   717   790
# 18           data scientist   235   351
# 19  artificial intelligence   220   228
# 20                      nlp    88    89
# 21                   python  1139  1195
# ...

# %%
import matplotlib.pyplot as plt
# Previous Data
fig=plt.subplots(figsize=(20,7))
# df['G']
# df['H']
plt.bar(df['Technology'],df['H'])
plt.xticks(rotation=90)
plt.show()

# %%
# Date April 22, 2021
fig,ax=plt.subplots(figsize=(20,7))
plt.bar(df['Technology'],df['I'])
plt.xticks(rotation=90)
# for i,j,z in zip(l3,df['H'],df['Change']):
#   ax.text(i,j,z,)
plt.show()

# %%
# Changes occur
df[['Technology','H','I']].plot(x='Technology',kind='bar',figsize=(20,7),)

# %%
l1=[]
l2=[]
def fun(x):
  if str(x)[0]=='-':
    l1.append(str(x)[1:])
    l2.append('Decrease')
    return (str(x)[1:],"Decrease")
  else:
    l1.append(str(x))
    l2.append('Increase')
    return (str(x),"Increase")

# %%
for i in range(len(df)):
  fun(round(((df['I'][i]-df['H'][i])/df['H'][i])*100,2))

# %%
df['% age1']=l1
df['Change1']=l2

# %%
# df

# %%
# Date May 5, 2021
fig,ax=plt.subplots(figsize=(20,7))
plt.bar(df['Technology'],df['J'])
plt.xticks(rotation=90)
# for i,j,z in zip(l3,df['H'],df['Change']):
#   ax.text(i,j,z,)
plt.show()

# %%
# Changes occur
df[['Technology','I','J']].plot(x='Technology',kind='bar',figsize=(20,7),)

# %%
l1=[]
l2=[]
def fun(x):
  if str(x)[0]=='-':
    l1.append(str(x)[1:])
    l2.append('Decrease')
    return (str(x)[1:],"Decrease")
  else:
    l1.append(str(x))
    l2.append('Increase')
    return (str(x),"Increase")

# %%
for i in range(len(df)):
  fun(round(((df['J'][i]-df['I'][i])/df['I'][i])*100,2))

# %%
df['% age2']=l1
df['Change2']=l2

# %%
df
# Out:
#                  Technology        A        B  ...   Change1  % age2   Change2
# 0             React Native     262.0    267.0  ...  Increase    9.48  Decrease
# 1                  React.js    425.0    423.0  ...  Decrease    5.83  Decrease
# 2                   Angular    364.0    366.0  ...  Increase   15.77  Decrease
# 3                   Node.js   1229.0   1217.0  ...  Decrease   10.17  Decrease
# 4                   mongodb   1347.0   1415.0  ...  Increase    13.9  Decrease
# 5                express.js     91.0     91.0  ...  Decrease    2.07  Decrease
# 6                    django    261.0    255.0  ...  Increase   26.67  Decrease
# 7                javascript   1255.0   1247.0  ...  Increase   11.17  Decrease
# 8                    Vue.js     95.0     97.0  ...  Decrease    1.53  Decrease
# 9                       sql  19452.0  18744.0  ...  Increase    13.2  Decrease
# 10                  flutter    492.0    471.0  ...  Increase    1.61  Decrease
# ...
